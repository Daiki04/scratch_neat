# %%
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots

# %%
df = pd.read_csv('result.csv')
df
# Out:
#     best_fitness  best_acc   fitness       acc  best_test_fitness  \
# 0      -0.482179  0.527362 -0.482179  0.527362          -0.377318
# 1      -0.100040  0.673070 -0.100040  0.673070          -0.089730
# 2      -0.083855  0.808184 -0.083855  0.808184          -0.062808
# 3      -0.026292  0.861372 -0.026292  0.861372          -0.042298
# 4      -0.020609  0.908714 -0.020609  0.908714          -0.015835
# 5      -0.020609  0.908714 -0.024936  0.951100          -0.015835
# 6      -0.020609  0.908714 -0.022781  0.973273          -0.015835
# 7      -0.011792  0.982231 -0.011792  0.982231          -0.017934
# 8      -0.011792  0.982231 -0.013380  0.985905          -0.017934
# 9      -0.006830  0.986186 -0.006830  0.986186          -0.009063
# 10     -0.005136  0.991163 -0.005136  0.991163          -0.011312
#
#     best_test_acc
# 0        0.527745
# 1        0.691458
# 2        0.798187
# 3        0.863254
# 4        0.920821
# 5        0.920821
# 6        0.920821
# ...

# %%
global_fitness = df['best_fitness']
global_acc = df['best_acc']
global_test_fitness = df['best_test_fitness']
global_test_acc = df['best_test_acc']
fitness = df['fitness']
acc = df['acc']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots

df = pd.read_csv('result.csv')

global_fitness = df['best_fitness']
global_acc = df['best_acc']
global_test_fitness = df['best_test_fitness']
global_test_acc = df['best_test_acc']
fitness = df['fitness']
acc = df['acc']

plt.style.use(['science', 'grid', 'no-latex'])

fig, ax = plt.subplots(2, 1, figsize=(6, 8))

ax[0].plot(global_fitness, label='Global Best Fitness')
ax[0].plot(fitness, label='Local Best Fitness', linestyle='--')
ax[0].set_xlabel('Iteration')
ax[0].set_ylabel('Fitness')
ax[0].legend()

ax[1].plot(global_acc, label='Global Best Accuracy')
ax[1].plot(acc, label='Local Best Accuracy', linestyle='--')
ax[1].set_xlabel('Iteration')
ax[1].set_ylabel('Accuracy')
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
import pickle
from genome import DefaultGenomes

with open('winner.pkl', 'rb') as f:
    winner = pickle.load(f)

# %%
genome = DefaultGenomes(0)
genome.load('winner.pkl')

# %%
enable_connections = []
for cg in genome.connections.values():
    if cg.enabled:
        enable_connections.append([cg.key, cg.weight])

in_key = [-i-1 for i in range(784)]
out_key = [0]

for cg in genome.connections.values():
    if cg.enabled:
        ink, outk = cg.key
        if ink > 0 and ink
# Out:
# 781

# %%
enable_connections
# Out:
# [[(-1, 0), 0.6001549892623863],
#  [(-2, 0), 1.8624083237418603],
#  [(-3, 0), 0.19282951176866553],
#  [(-4, 0), 0.6039103133517574],
#  [(-5, 0), 0.15144073278204112],
#  [(-6, 0), -0.23350647826326906],
#  [(-7, 0), 1.3515989610229133],
#  [(-8, 0), -0.5016969005620979],
#  [(-9, 0), -0.14429423485467036],
#  [(-10, 0), -0.09488369388812767],
#  [(-11, 0), -1.6363583332568905],
#  [(-12, 0), 0.13645368985077147],
#  [(-13, 0), 2.981580564920258],
#  [(-14, 0), -0.39330771485628235],
#  [(-15, 0), 0.004565732829496402],
#  [(-16, 0), 0.6542459696231918],
#  [(-17, 0), -1.443370576132956],
#  [(-18, 0), -0.12696488109894644],
#  [(-19, 0), 0.1198092891444233],
#  [(-20, 0), -0.419433567631637],
#  [(-21, 0), -1.5952392706924616],
#  [(-22, 0), -0.8958872729908358],
#  [(-23, 0), 0.24949121048436593],
#  [(-24, 0), -2.1743513024305967],
#  [(-25, 0), 1.6810874046497972],
#  [(-26, 0), -1.181020035707205],
#  [(-27, 0), 1.9774599375469677],
#  [(-28, 0), 0.5859925268237914],
# ...
